# %% [markdown]
# ## Part 1: Data Comprehension

# %% [markdown]
# # Imports
# **Import pandas, seaborn, matplotlib**

# %% [markdown]
# A) Which NBA team drafted the most players who went to Duke and were drafted in or before the 2000 draft?

# %%
import pandas as pd 
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Get the Data**
#
# Working with the NBA Players Draft csv file. Containing player information such as name, college and draft team. There are also numerical columns:
#
#    * Overall_pick
#    * years_active
#    * games
#    * minutes_played
#    * points:
#    * total_rebounds
#    * assist
#    * etc...
#
# **Read in NBA Players Draft csv file as a DataFrame called players**

# %%
players = pd.read_csv("nbaplayersdraft.csv")

# %% [markdown]
# **Check the head of players, and check out its info() and describe() methods.**

# %%
players.head()
# Out:
#    id  year  rank  overall_pick team          player     college  \
# 0   1  1989     1             1  SAC  Pervis Ellison  Louisville
# 1   2  1989     2             2  LAC     Danny Ferry        Duke
# 2   3  1989     3             3  SAS    Sean Elliott     Arizona
# 3   4  1989     4             4  MIA       Glen Rice    Michigan
# 4   5  1989     5             5  CHH       J.R. Reid         UNC
#
#    years_active   games  minutes_played  ...  3_point_percentage  \
# 0          11.0   474.0         11593.0  ...               0.050
# 1          13.0   917.0         18133.0  ...               0.393
# 2          12.0   742.0         24502.0  ...               0.375
# 3          15.0  1000.0         34985.0  ...               0.400
# 4          11.0   672.0         15370.0  ...               0.135
#
#    free_throw_percentage  average_minutes_played  points_per_game  \
# 0                  0.689                    24.5              9.5
# ...

# %%
players.describe()
# Out:
#                 id         year         rank  overall_pick  years_active  \
# count  1922.000000  1922.000000  1922.000000   1922.000000   1669.000000
# mean    961.500000  2005.317378    29.694589     29.694589      6.332534
# std     554.977927     9.456946    16.912454     16.912454      4.656321
# min       1.000000  1989.000000     1.000000      1.000000      1.000000
# 25%     481.250000  1997.000000    15.000000     15.000000      2.000000
# 50%     961.500000  2005.000000    30.000000     30.000000      5.000000
# 75%    1441.750000  2013.000000    44.000000     44.000000     10.000000
# max    1922.000000  2021.000000    60.000000     60.000000     22.000000
#
#              games  minutes_played        points  total_rebounds  \
# count  1669.000000     1669.000000   1669.000000     1669.000000
# mean    348.042540     8399.055722   3580.413421     1497.009587
# std     324.897567     9845.871529   4826.142847     2003.686388
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1922 entries, 0 to 1921
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1922 non-null   int64
#  1   year                       1922 non-null   int64
#  2   rank                       1922 non-null   int64
#  3   overall_pick               1922 non-null   int64
#  4   team                       1922 non-null   object
#  5   player                     1922 non-null   object
#  6   college                    1585 non-null   object
#  7   years_active               1669 non-null   float64
#  8   games                      1669 non-null   float64
#  9   minutes_played             1669 non-null   float64
#  10  points                     1669 non-null   float64
#  11  total_rebounds             1669 non-null   float64
#  12  assists                    1669 non-null   float64
# ...

# %%
#Convert Team, Player and College to string type

players = players.astype({'player':'string', 'team':'string', 'college':'string'})
print(players.dtypes)
# Out:
# id                             int64
# year                           int64
# rank                           int64
# overall_pick                   int64
# team                          string
# player                        string
# college                       string
# years_active                 float64
# games                        float64
# minutes_played               float64
# points                       float64
# total_rebounds               float64
# assists                      float64
# field_goal_percentage        float64
# 3_point_percentage           float64
# free_throw_percentage        float64
# average_minutes_played       float64
# points_per_game              float64
# average_total_rebounds       float64
# average_assists              float64
# win_shares                   float64
# win_shares_per_48_minutes    float64
# box_plus_minus               float64
# value_over_replacement       float64
# dtype: object

# %%
players[(players['college']=='Duke') & (players['year'] <= 2000)]
# Out:
#       id  year  rank  overall_pick team              player college  \
# 1      2  1989     2             2  LAC         Danny Ferry    Duke
# 78    79  1990    25            25  POR      Alaa Abdelnaby    Duke
# 102  103  1990    49            49  DAL      Phil Henderson    Duke
# 164  165  1992     3             3  MIN  Christian Laettner    Duke
# 209  210  1992    48            48  PHO         Brian Davis    Duke
# 222  223  1993     7             7  SAC        Bobby Hurley    Duke
# 254  255  1993    39            39  IND         Thomas Hill    Duke
# 272  273  1994     3             3  DET          Grant Hill    Duke
# 298  299  1994    29            29  PHO        Antonio Lang    Duke
# 335  336  1995    12            12  DAL      Cherokee Parks    Duke
# 364  365  1995    41            41  HOU           Erik Meek    Duke
# 516  517  1998    20            20  ATL      Roshown McLeod    Duke
# 555  556  1999     1             1  CHI         Elton Brand    Duke
# ...

# %% [markdown]
# A)
# b. have the first name that begins with D and were drafted in an even year (1990,1992,1994 etc)

# %%
players['player'][0:]
# Out:
# 0             Pervis Ellison
# 1                Danny Ferry
# 2               Sean Elliott
# 3                  Glen Rice
# 4                  J.R. Reid
#                 ...
# 1917           Scottie Lewis
# 1918         Balša Koprivica
# 1919            Jericho Sims
# 1920            RaiQuan Gray
# 1921    Georgios Kalaitzakis
# Name: player, Length: 1922, dtype: string

# %%
players[players['year'] %2==0 ]
# Out:
#         id  year  rank  overall_pick team              player  \
# 54      55  1990     1             1  NJN     Derrick Coleman
# 55      56  1990     2             2  SEA         Gary Payton
# 56      57  1990     3             3  DEN  Mahmoud Abdul-Rauf
# 57      58  1990     4             4  ORL        Dennis Scott
# 58      59  1990     5             5  CHH        Kendall Gill
# ...    ...   ...   ...           ...  ...                 ...
# 1857  1858  2020    56            56  CHO        Grant Riller
# 1858  1859  2020    57            57  LAC        Reggie Perry
# 1859  1860  2020    58            58  PHI           Paul Reed
# 1860  1861  2020    59            59  TOR        Jalen Harris
# 1861  1862  2020    60            60  NOP         Sam Merrill
#
#                     college  years_active   games  minutes_played  ...  \
# 54                 Syracuse          15.0   781.0         25903.0  ...
# 55             Oregon State          17.0  1335.0         47117.0  ...
# ...

# %% [markdown]
# B) Describe the relationship between a teams first round pick slot in one year with their first round slot in the subsequent year

# %%
#create df with 1st round picks

fr = players[players['overall_pick'] <=30]

# %%
fr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 988 entries, 0 to 1891
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         988 non-null    int64
#  1   year                       988 non-null    int64
#  2   rank                       988 non-null    int64
#  3   overall_pick               988 non-null    int64
#  4   team                       988 non-null    string
#  5   player                     988 non-null    string
#  6   college                    835 non-null    string
#  7   years_active               976 non-null    float64
#  8   games                      976 non-null    float64
#  9   minutes_played             976 non-null    float64
#  10  points                     976 non-null    float64
#  11  total_rebounds             976 non-null    float64
#  12  assists                    976 non-null    float64
# ...

# %%
fr.describe()
# Out:
#                 id         year        rank  overall_pick  years_active  \
# count   988.000000   988.000000  988.000000    988.000000    976.000000
# mean    929.297571  2005.007085   15.472672     15.472672      7.765369
# std     558.126809     9.535034    8.647215      8.647215      4.702784
# min       1.000000  1989.000000    1.000000      1.000000      1.000000
# 25%     447.750000  1997.000000    8.000000      8.000000      4.000000
# 50%     918.500000  2005.000000   15.000000     15.000000      7.000000
# 75%    1405.250000  2013.000000   23.000000     23.000000     11.000000
# max    1892.000000  2021.000000   30.000000     30.000000     22.000000
#
#              games  minutes_played        points  total_rebounds  \
# count   976.000000      976.000000    976.000000      976.000000
# mean    451.771516    11488.849385   5017.134221     2076.469262
# std     332.543876    10667.323218   5433.228564     2245.043203
# ...

# %%
fr.head()
# Out:
#    id  year  rank  overall_pick team          player     college  \
# 0   1  1989     1             1  SAC  Pervis Ellison  Louisville
# 1   2  1989     2             2  LAC     Danny Ferry        Duke
# 2   3  1989     3             3  SAS    Sean Elliott     Arizona
# 3   4  1989     4             4  MIA       Glen Rice    Michigan
# 4   5  1989     5             5  CHH       J.R. Reid         UNC
#
#    years_active   games  minutes_played  ...  3_point_percentage  \
# 0          11.0   474.0         11593.0  ...               0.050
# 1          13.0   917.0         18133.0  ...               0.393
# 2          12.0   742.0         24502.0  ...               0.375
# 3          15.0  1000.0         34985.0  ...               0.400
# 4          11.0   672.0         15370.0  ...               0.135
#
#    free_throw_percentage  average_minutes_played  points_per_game  \
# 0                  0.689                    24.5              9.5
# ...

# %%
# Matrix form for correlation data 
fr.corr()
# Out:
# /var/folders/vr/vzrh0wms6jq_j43dpf8nlk6h0000gn/T/ipykernel_35906/796461182.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fr.corr()
#                                  id      year      rank  overall_pick  \
# id                         1.000000  0.999746  0.016702      0.016702
# year                       0.999746  1.000000  0.001164      0.001164
# rank                       0.016702  0.001164  1.000000      1.000000
# overall_pick               0.016702  0.001164  1.000000      1.000000
# years_active              -0.429215 -0.420195 -0.301993     -0.301993
# games                     -0.381840 -0.373156 -0.319909     -0.319909
# minutes_played            -0.326773 -0.317833 -0.378531     -0.378531
# points                    -0.251991 -0.243013 -0.403906     -0.403906
# ...

# %%
sns.heatmap(fr.corr())
# Out:
# /var/folders/vr/vzrh0wms6jq_j43dpf8nlk6h0000gn/T/ipykernel_35906/2453180456.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(fr.corr())
# <Axes: >

# %%
fr.pivot_table(values = 'rank',index= 'year',columns = 'team')
# Out:
# team        ATL        BOS   BRK   CHA   CHH        CHI   CHO   CLE  \
# year
# 1989  23.000000  13.000000   NaN   NaN  17.0  14.666667   NaN  25.0
# 1990  10.000000  19.000000   NaN   NaN   5.0  29.000000   NaN   NaN
# 1991  18.000000  24.000000   NaN   NaN  14.5  26.000000   NaN  11.0
# 1992  10.000000  21.000000   NaN   NaN   2.0  27.000000   NaN   NaN
# 1993  15.000000  19.000000   NaN   NaN  18.5  25.000000   NaN  22.0
# 1994        NaN   9.000000   NaN   NaN   NaN  21.000000   NaN   NaN
# 1995  16.000000  14.000000   NaN   NaN  22.0  20.000000   NaN  17.0
# 1996  28.000000   6.000000   NaN   NaN  14.5  29.000000   NaN  16.0
# 1997  22.000000   4.500000   NaN   NaN   NaN  28.000000   NaN  14.5
# 1998  20.000000  10.000000   NaN   NaN  21.0  28.000000   NaN   NaN
# 1999  18.500000        NaN   NaN   NaN   3.0   8.500000   NaN   9.5
# 2000   6.000000  11.000000   NaN   NaN  19.0  11.666667   NaN   8.0
# 2001   3.000000  14.000000   NaN   NaN  16.0  17.000000   NaN  14.0
# ...

# %%
pvfr = fr.pivot_table(values = 'rank',index= 'team',columns = 'year')
sns.heatmap(pvfr)
# Out:
# <Axes: xlabel='year', ylabel='team'>

# %%
pvfr.isna()
# Out:
# year   1989   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# team
# ATL   False  False  False  False  False   True  False  False  False  False
# BOS   False  False  False  False  False  False  False  False  False  False
# BRK    True   True   True   True   True   True   True   True   True   True
# CHA    True   True   True   True   True   True   True   True   True   True
# CHH   False  False  False  False  False   True  False  False   True  False
# CHI   False  False  False  False  False  False  False  False  False  False
# CHO    True   True   True   True   True   True   True   True   True   True
# CLE   False   True  False   True  False   True  False  False  False   True
# DAL   False   True  False  False  False  False  False  False  False  False
# DEN   False  False  False  False  False  False  False  False  False  False
# DET   False  False   True  False  False  False  False  False  False  False
# ...

# %%
pvfr1 = pvfr.interpolate()

# %%
pvfr1 = pvfr.interpolate()
sns.heatmap(pvfr1, cmap='magma')
# Out:
# <Axes: xlabel='year', ylabel='team'>

# %% [markdown]
# **Resources:**
#
# - https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/learn/lecture/5784222?start=15#overview
# - https://stackoverflow.com/questions/11285613/selecting-multiple-columns-in-a-pandas-dataframe
# - https://docs.python.org/3/library/re.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html
